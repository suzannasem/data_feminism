# %%
import pandas as pd 
import numpy as np

# %%
df_example = pd.read_csv('audible_uncleaned.csv')
df_example
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
# ...

# %%
## AUTHOR

# %%
import matplotlib.pyplot as plt

valueCounts = df_example['author'].head(100).value_counts()

valueCounts.plot(kind='bar')
# Out:
# <Axes: xlabel='author'>

# %%
## NARRATOR

# %%
## TIME
def convertTime(timeString):
    totalMins = 0
    splitString = timeString.split(' and ')
    for item in splitString:
        if 'hrs' in item:
            hours = int(item.split(' ')[0])
            totalMins += (60*hours)
        elif 'mins' in item:
            mins = int(item.split(' ')[0])
            totalMins += mins
    return totalMins

df_example['time'] = df_example['time'].apply(convertTime)
df_example
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
# ...

# %%
## RELEASE DATE

df_example['releasedate'] = pd.to_datetime(df_example["releasedate"], infer_datetime_format=True, format='mixed').dt.strftime('%Y-%m-%d')
df_example
# Out:
# /tmp/ipykernel_5831/1596848135.py:3: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df_example['releasedate'] = pd.to_datetime(df_example["releasedate"], infer_datetime_format=True, format='mixed').dt.strftime('%Y-%m-%d')
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# ...

# %%
## STARS

notRated = df_example[df_example['stars'] == 'Not rated yet']
rated = df_example[df_example['stars'] != 'Not rated yet']

rated
# Out:
#                                              name                      author  \
# 0                      Geronimo Stilton #11 & #12   Writtenby:GeronimoStilton
# 1                                The Burning Maze       Writtenby:RickRiordan
# 2                                    The Deep End        Writtenby:JeffKinney
# 3                            Daughter of the Deep       Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1       Writtenby:RickRiordan
# ...                                           ...                         ...
# 87228                                  Why We Fly          Writtenby:EvanRail
# 87337                                  River Town      Writtenby:PeterHessler
# 87340                      Figures in a Landscape       Writtenby:PaulTheroux
# 87362                             Tower of London            Writtenby:iMinds
# 87477                          Tigers in the Snow  Writtenby:PeterMatthiessen
#
# ...

# %%
rated[['stars', 'numRatings']] = rated['stars'].str.split('stars', expand = True)
rated
# Out:
# /tmp/ipykernel_5831/4091466616.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rated[['stars', 'numRatings']] = rated['stars'].str.split('stars', expand = True)
# /tmp/ipykernel_5831/4091466616.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rated[['stars', 'numRatings']] = rated['stars'].str.split('stars', expand = True)
#                                              name                      author  \
# ...

# %%
rated['stars'] = rated['stars'].str.split( ' out of ').str[0].astype(float)
# take column as pandas series
# split string @ 'out of'
# take 1st value in string (the # / 5)
# report as a float
rated
# Out:
# /tmp/ipykernel_5831/633787248.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rated['stars'] = rated['stars'].str.split( ' out of ').str[0].astype(float)
#                                              name                      author  \
# 0                      Geronimo Stilton #11 & #12   Writtenby:GeronimoStilton
# 1                                The Burning Maze       Writtenby:RickRiordan
# 2                                    The Deep End        Writtenby:JeffKinney
# 3                            Daughter of the Deep       Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1       Writtenby:RickRiordan
# ...                                           ...                         ...
# ...

# %% [markdown]
# ## Try this yourself with the survey data we've been generating. Examine the columns and pick one to attempt to "clean" up. What do you want to accomplish? How are you planning to do so? Try to this with python code.

# %%
df_class = pd.read_csv('survey_b215.csv')

## CLEANING UP FRUIT

# my goal is to remove values without entries, normalize with the lower function, remove extraneous words by slicing each entry by spaces
# to produce a final df of lowercase, single-word fruit entries
# which we can classify and plot according to frequencies

# remove NaNs (interpret as people who do not like fruit and/or declined to answer)

df_fruit = df_class.dropna(subset = ['Fruit'])
# make all fruits the same (.lower())

for entry in df_fruit['Fruit']: # for each entry (each fruit)
    
    littleFruit = str(entry).lower() # make it lowercase, store in variable little Fruit
    oneFruit = littleFruit.split(' ') # new variable onefruit splits by spaces

    for yum in oneFruit: # for each entry (string) in one Fruit (lists)
        print(yum)
        # if len(yum) < 3: # fruits are more than 3 letters
            # print(oneFruit.remove(yum)) # remove shorties who aren't fruits 
            # this ended up adding the entry "None" wherever there was a non-fruit value
            # instead of actually removing the non-fruit value

            # next: store oneFruit with removed values in a df


# bar plot of frequencies of each fruit

# in a perfect world, convert df into frequencies with value counts
# use matplotlib to plot
# Out:
# pineapple
# kiwi
# mango
# pomegranate
#
# strawberry
# peach
# mango
# apple
# pomegranate
#
# strawberry
# blackberry
# kiwi
# banana
# pineapple
# mango
# coconut
# dragonfruit
# pear
# strawberry
# a
# mango
# pomegranate
